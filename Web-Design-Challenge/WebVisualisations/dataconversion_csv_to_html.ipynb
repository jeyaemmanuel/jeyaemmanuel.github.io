# %%
import pandas as pd

# %%
df = pd.read_csv('Resources\WeatherData.csv')

# %%
csv_to_html = df.to_html()
print(csv_to_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>74.16</td>
#       <td>76</td>
#       <td>2</td>
#       <td>6.62</td>
#       <td>PF</td>
#       <td>1658289087</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>avarua</td>
#       <td>-21.2078</td>
#       <td>-159.7750</td>
#       <td>75.25</td>
#       <td>69</td>
#       <td>40</td>
#       <td>6.91</td>
#       <td>CK</td>
#       <td>1658289087</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>victoria</td>
#       <td>22.2855</td>
#       <td>114.1577</td>
# ...
